# %% [markdown]
# <a href="https://colab.research.google.com/github/EmanuelHC/TaskMatrix/blob/POC/POC_VisualChatGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download visual-chatgpt

# %%
# !rm -rf TaskMatrix && git clone https://github.com/EmanuelHC/TaskMatrix
# Out:
# Cloning into 'TaskMatrix'...
# remote: Enumerating objects: 574, done.
# remote: Counting objects: 100% (574/574), done.
# remote: Compressing objects: 100% (355/355), done.
# remote: Total 574 (delta 217), reused 523 (delta 200), pack-reused 0
# Receiving objects: 100% (574/574), 40.24 MiB | 24.24 MiB/s, done.
# Resolving deltas: 100% (217/217), done.

# %% [markdown]
# Go to directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd TaskMatrix/
# Out:
# /content/TaskMatrix

# %% [markdown]
# Install packages

# %%
# !pip install -r requirements.txt
# !pip install git+https://github.com/IDEA-Research/GroundingDINO.git
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.0/344.0 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 29.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.4/202.4 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.1/989.1 kB 36.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# Set your OPENAI_API_KEY

# %%
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %% [markdown]
# Import dependencies

# %%
from visual_chatgpt import *
# Out:
# /usr/local/lib/python3.10/dist-packages/controlnet_aux/mediapipe_face/mediapipe_face_common.py:7: UserWarning: The module 'mediapipe' is not installed. The package will have limited functionality. Please install it using the command: pip install 'mediapipe'
#   warnings.warn(

# %% [markdown]
# Run VisualChatGPT

# %%
# !mkdir -p checkpoints
# load = "ImageCaptioning_cuda:0,Text2Image_cuda:0"
#load = "Text2Box_cuda:0,Segmenting_cuda:0,Inpainting_cuda:0,ImageCaptioning_cuda:0"
#load = "ImageCaptioning_cuda:0,Text2Image_cuda:0,Inpainting_cuda:0,InstructPix2Pix_cuda:0"
#load ="Inpainting_cuda:0,ImageCaptioning_cuda:0,VisualQuestionAnswering_cuda:0"
#load ="ImageCaptioning_cuda:0,Text2Image_cuda:0,Segmenting_cuda:0"
load ="ImageCaptioning_cuda:0,VisualQuestionAnswering_cuda:0,InstructPix2Pix_cuda:0"


load_dict = {e.split('_')[0].strip(): e.split('_')[1].strip() for e in load.split(',')}
bot = ConversationBot(load_dict=load_dict)
with gr.Blocks(css="#chatbot .overflow-y-auto{height:500px}; body {background-color: purple;}") as demo:
    lang = gr.Radio(choices = ['Chinese','English'], value=None, label='Language')
    chatbot = gr.Chatbot(elem_id="chatbot", label="Visual ChatGPT")
    state = gr.State([])
    with gr.Row(visible=False) as input_raws:
        with gr.Column(scale=0.7):
            txt = gr.Textbox(show_label=False, placeholder="Enter text and press enter, or upload an image").style(
                container=False)
        with gr.Column(scale=0.15, min_width=0):
            clear = gr.Button("Clear️")
        with gr.Column(scale=0.15, min_width=0):
            btn = gr.UploadButton("🖼️", file_types=["image"])
    lang.change(bot.init_agent, [lang], [input_raws, lang, txt, clear])
    txt.submit(bot.run_text, [txt, state], [chatbot, state])
    txt.submit(lambda: "", None, txt)
    btn.upload(bot.run_image, [btn, state, txt, lang], [chatbot, state, txt])
    clear.click(bot.memory.clear)
    clear.click(lambda: [], None, chatbot)
    clear.click(lambda: [], None, state)
    demo.launch(server_name="0.0.0.0", server_port=7860, share=True, debug=True)
# Out:
# Initializing VisualChatGPT, load_dict={'ImageCaptioning': 'cuda:0', 'VisualQuestionAnswering': 'cuda:0', 'InstructPix2Pix': 'cuda:0'}
# Initializing ImageCaptioning to cuda:0
# ...
# Initializing VisualQuestionAnswering to cuda:0
# ...
# Initializing InstructPix2Pix to cuda:0
# ...
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# You have passed a non-standard module StableDiffusionSafetyChecker(
#   (vision_model): CLIPVisionModel(
#     (vision_model): CLIPVisionTransformer(
#       (embeddings): CLIPVisionEmbeddings(
# ...

# %%
#!ps -aux | grep "python"
#!kill -9 7507

# %%
# !python visual_chatgpt.py --load "ImageCaptioning_cuda:0,Text2Image_cuda:0"

# %%
# !ls image/
